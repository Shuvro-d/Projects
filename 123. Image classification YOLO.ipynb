# %%
# !pip install segmentation-models
# !pip install tensorflow
# !pip install --upgrade --no-cache-dir gdown
# !gdown --id 1tGdUa2M56hJ0Fl5csgWH4MzqrWO-0Pax

# !pip install patool
import patoolib
patoolib.extract_archive('dataset.zip')
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 KB 2.8 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# ...
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:121: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1tGdUa2M56hJ0Fl5csgWH4MzqrWO-0Pax
# To: /content/dataset.zip
# 100% 156M/156M [00:05<00:00, 27.0MB/s]
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.2/78.2 GB disk)

# %%
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-cls' for x in p5]  # classification models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# ...
#   0%|          | 0.00/4.87M [00:00<?, ?B/s]
# ...
#   0%|          | 0.00/10.5M [00:00<?, ?B/s]
# ...
#   0%|          | 0.00/24.9M [00:00<?, ?B/s]
# ...
#   0%|          | 0.00/50.9M [00:00<?, ?B/s]
# ...
#   0%|          | 0.00/92.0M [00:00<?, ?B/s]

# %%
# %cd ../yolov5
# !python classify/train.py --model yolov5s-cls.pt --data /content/dataset --epochs 100 --img 128 --pretrained weights/yolov5s-cls.pt

# %%
# %cd ../yolov5
# !python classify/train.py --model yolov5l-cls.pt --data /content/dataset --epochs 100 --img 128 --pretrained weights/yolov5s-cls.pt
# Out:
# /content/yolov5
# classify/train: model=yolov5l-cls.pt, data=/content/dataset, epochs=100, batch_size=64, imgsz=128, nosave=False, cache=None, device=, workers=8, project=runs/train-cls, name=exp, exist_ok=False, pretrained=weights/yolov5s-cls.pt, optimizer=Adam, lr0=0.001, decay=5e-05, label_smoothing=0.1, cutoff=None, dropout=None, verbose=False, seed=0, local_rank=-1
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# TensorBoard: Start with 'tensorboard --logdir runs/train-cls', view at http://localhost:6006/
# 2023-02-27 15:50:37.620285: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !python classify/val.py --weights runs/train-cls/exp/weights/best.pt --data /content/dataset
# Out:
# classify/val: data=/content/dataset, weights=['runs/train-cls/exp/weights/best.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=runs/val-cls, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-100-g4d28fec Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 215 layers, 25260100 parameters, 0 gradients, 68.3 GFLOPs
# testing: 100% 11/11 [00:05<00:00,  2.17it/s]
#                    Class      Images    top1_acc    top5_acc
#                      all        1311       0.952           1
#                   glioma         300        0.97           1
#               meningioma         306       0.899           1
#                  notumor         405       0.993           1
#                pituitary         300       0.933           1
# Speed: 0.1ms pre-process, 1.1ms inference, 0.0ms post-process per image at shape (1, 3, 224, 224)
# Results saved to runs/val-cls/exp

# %%
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source /content/a.jpg
# Out:
# classify/predict: weights=['runs/train-cls/exp/weights/best.pt'], source=/content/a.jpg, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-114-g3c0a6e6 Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 215 layers, 25260100 parameters, 0 gradients, 68.3 GFLOPs
# image 1/1 /content/a.jpg: 224x224 glioma 0.91, meningioma 0.04, notumor 0.03, pituitary 0.02, 10.7ms
# Speed: 0.3ms pre-process, 10.7ms inference, 0.2ms NMS per image at shape (1, 3, 224, 224)
# Results saved to runs/predict-cls/exp

# %%
print("+++++++++++++++++++++           Glioma                   ++++++++++++++++++++++++++++++++++")
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source /content/dataset/test/glioma
print("+++++++++++++++++++++           Meningioma               ++++++++++++++++++++++++++++++++++")
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source /content/dataset/test/meningioma
print("+++++++++++++++++++++           Notumor                  ++++++++++++++++++++++++++++++++++")
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source /content/dataset/test/notumor
print("+++++++++++++++++++++           Pituitary                ++++++++++++++++++++++++++++++++++")
# !python classify/predict.py --weights runs/train-cls/exp/weights/best.pt --source /content/dataset/test/pituitary
# Out:
# +++++++++++++++++++++           Glioma                   ++++++++++++++++++++++++++++++++++
# classify/predict: weights=['runs/train-cls/exp/weights/best.pt'], source=/content/dataset/test/glioma, data=data/coco128.yaml, imgsz=[224, 224], device=, view_img=False, save_txt=False, nosave=False, augment=False, visualize=False, update=False, project=runs/predict-cls, name=exp, exist_ok=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-100-g4d28fec Python-3.8.10 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 215 layers, 25260100 parameters, 0 gradients, 68.3 GFLOPs
# image 1/300 /content/dataset/test/glioma/Te-glTr_0000.jpg: 224x224 glioma 0.95, meningioma 0.03, notumor 0.01, pituitary 0.01, 9.8ms
# image 2/300 /content/dataset/test/glioma/Te-glTr_0001.jpg: 224x224 glioma 0.95, meningioma 0.02, notumor 0.01, pituitary 0.01, 9.8ms
# ...

# %%
x=[]
for i in range(1311):
  x.append("x")
print(len(x))
# Out:
# 1311

# %%
y=[]
for i in range(1311):
  if i<=50:
    y.append("y")
  else:
    y.append("x")
print(len(y))
# Out:
# 1311

# %%
import numpy as np
from sklearn import svm
import glob
import cv2
import os
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, precision_score, recall_score
accuracy = accuracy_score(x, y)
precision = precision_score(x, y, average='macro')
recall = recall_score(x, y, average='macro')
print('Test accuracy:', accuracy)
print('Test precision:', precision)
print('Test recall:', recall)
# Out:
# Test accuracy: 0.9610983981693364
# Test precision: 0.5
# Test recall: 0.4805491990846682
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
